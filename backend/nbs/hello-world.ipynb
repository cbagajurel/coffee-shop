# %%
print("Hello World")
# Out:
# Hello World

# %%
# %pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.4-cp314-cp314-macosx_10_13_universal2.whl.metadata (37 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nrngajurel/Desktop/flutter/coffee_shop/.venv/lib/python3.14/site-packages (from requests) (3.11)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp314-cp314-macosx_10_13_universal2.whl (207 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Installing collected packages: urllib3, charset_normalizer, certifi, requests
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [requests]
# Successfully installed certifi-2025.11.12 charset_normalizer-3.4.4 requests-2.32.5 urllib3-2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
endpoint = "/healthz"
base_url = "http://localhost:8000"
endpoint = f"{base_url}{endpoint}"
endpoint
# Out:
# 'http://localhost:8000/healthz'

# %%
response = requests.get(endpoint)
print(response.ok)
# Out:
# True
