# %%
import requests

# %%
endpoint = "/api/events/43"
base_url = "http://localhost:8000"
endpoint = f"{base_url}{endpoint}"
endpoint
# Out:
# 'http://localhost:8000/api/events/43'

# %%
response = requests.get(endpoint)
response.json()
# Out:
# {'message': 'Event 43'}

# %%
if response.ok:
    data = response.json()
    print(data, type(data))
else:
    print(response.status_code)
    print(response.text)
# Out:
# {'message': 'Event 43'} <class 'dict'>
